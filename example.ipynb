# %%
from corpus import get_info

# %%
get_info('Модель')
# Out:
# Общее число упомнианий:  209
# Часть речи:  NOUN
# Тип связи:  obj
# Морфологические признаки:  {'Animacy': 'Inan', 'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Plur'}
# Предложениe: - Мы разработали стоматологический антропоморфный робот-тренажёр, который позволит объективно оценить навыки студента, используя несколько моделей зубов, включая «смарт-зубы» с набором датчиков.
# Синтаксический разбор:
#           ┌──► -                 punct
#           │ ┌► Мы                nsubj
# ┌───┌───┌─└─└─ разработали
# │   │   │ ┌──► стоматологический amod
# │   │   │ │ ┌► антропоморфный    amod
# │ ┌─│ ┌─└►└─└─ робот-тренажёр    obj
# │ │ │ │   ┌──► ,                 punct
# │ │ │ │   │ ┌► который           nsubj
# │ │ │ └►┌─└─└─ позволит          acl:relcl
# │ │ │   │   ┌► объективно        advmod
# │ │ │   └►┌─└─ оценить           xcomp
# │ │ │ ┌─┌─└►┌─ навыки            obj
# │ │ │ │ │   └► студента          nmod
# │ │ │ │ │   ┌► ,                 punct
# ...

# %%
get_info('сделка')
# Out:
# Общее число упомнианий:  137
# Часть речи:  NOUN
# Тип связи:  nmod
# Морфологические признаки:  {'Animacy': 'Inan', 'Case': 'Loc', 'Gender': 'Fem', 'Number': 'Sing'}
# Предложениe: В этой ситуации можно было рискнуть и купить акции "Яндекса" по низкой цене, предполагая, что сделка не состоится, и после этого акции снова вырастут, позволяя их продать с прибылью.После объявления о сделке акции как покупателя, так и приобретаемой компании могут подорожать.
# Синтаксический разбор:
#                               ┌──► В             case
#                               │ ┌► этой          det
#           ┌──────────────────►└─└─ ситуации      obl
# ┌─────────│                   ┌─┌─ можно
# │         │                   │ └► было          cop
# │         │                 ┌─└──► рискнуть      csubj
# │         │                 │   ┌► и             cc
# │         │                 └►┌─└─ купить        conj
# │ ┌───────│                 ┌─└──► акции         obj
# ...
